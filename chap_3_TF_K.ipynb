# %% [markdown]
# # 3. Keras + TensorFlow
# ### Practice Notebook
# ---
# *by Pablo Bauer*

# %% [markdown]
# #### Import libraries

# %%
import tensorflow as tf
x = tf.ones(shape=(2,1))

# %%
print(x)
# Out:
# tf.Tensor(
# [[1.]
#  [1.]], shape=(2, 1), dtype=float32)

# %%
x = tf.zeros(shape=(2,1))

# %%
print(x)
# Out:
# tf.Tensor(
# [[0.]
#  [0.]], shape=(2, 1), dtype=float32)

# %%
random_tensor = tf.random.normal(shape=(3,1), mean=0., stddev=1.)

# %%
print(random_tensor)
# Out:
# tf.Tensor(
# [[-0.9428334]
#  [ 1.1459739]
#  [ 1.0967115]], shape=(3, 1), dtype=float32)

# %%
variable = tf.Variable(initial_value=tf.random.normal(shape=(3,1)))
variable
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=float32, numpy=
# array([[ 0.89163136],
#        [-0.52555245],
#        [-0.55034304]], dtype=float32)>

# %%
variable.assign(tf.ones(shape=(3,1)))
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 1) dtype=float32, numpy=
# array([[1.],
#        [1.],
#        [1.]], dtype=float32)>

# %%
variable
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=float32, numpy=
# array([[1.],
#        [1.],
#        [1.]], dtype=float32)>

# %%
variable[0,0].assign((3))
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 1) dtype=float32, numpy=
# array([[3.],
#        [1.],
#        [1.]], dtype=float32)>

# %%
variable.assign_add(tf.ones((3,1)))
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 1) dtype=float32, numpy=
# array([[4.],
#        [2.],
#        [2.]], dtype=float32)>

# %%
variable
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=float32, numpy=
# array([[4.],
#        [2.],
#        [2.]], dtype=float32)>
